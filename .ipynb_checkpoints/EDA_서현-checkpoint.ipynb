# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

import seaborn as sns
# %matplotlib inline
plt.rcParams['font.family'].insert(0, 'Malgun Gothic')
sns.set(font="Malgun Gothic", rc = {"axes.unicode_minus":False}, style='whitegrid')
plt.rcParams["figure.figsize"] = (15, 6)

from tqdm import notebook
import time

# %%
filename = list()
for f in os.listdir('../Data'):
    filename.append(f)
filename
# Out:
# ['LPOINT_BIG_COMP_01_DEMO.csv',
#  'LPOINT_BIG_COMP_02_PDDE.csv',
#  'LPOINT_BIG_COMP_03_COP_U.csv',
#  'LPOINT_BIG_COMP_04_PD_CLAC.csv',
#  'LPOINT_BIG_COMP_05_BR.csv',
#  'LPOINT_BIG_COMP_06_LPAY.csv']

# %%
DEMO = pd.read_csv(os.path.join('../Data', filename[0])) #고객데모정보
PDDE = pd.read_csv(os.path.join('../Data', filename[1])) #유통사 상품 구매 내역
COP_U = pd.read_csv(os.path.join('../Data', filename[2])) #제휴사 서비스 이용 내역
PD_CLAC = pd.read_csv(os.path.join('../Data', filename[3])) #유통사 상품 카테고리 마스터
BR = pd.read_csv(os.path.join('../Data', filename[4])) #유통사/제휴사 점포 마스터
LPAY = pd.read_csv(os.path.join('../Data', filename[5])) #엘페이 결제 내역
# Out:
# C:\Users\Seohyeon\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
DEMO.rename(columns={'cust':'고객번호', 'ma_fem_dv':'성별', 'ages':'연령대', 'zon_hlv':'거주지'}, inplace=True)
PDDE.rename(columns={'cust':'고객번호', 'rct_no':'영수증', 'chnl_dv':'채널', 'cop_c':'제휴사', 'pd_c':'상품코드', 'br_c':'점포코드', 'de_dt':'이용일자', 'de_hr':'이용시간', 'buy_am':'이용금액', 'buy_ct':'구매수량'}, inplace=True)
COP_U.rename(columns={'cust':'고객번호', 'rct_no':'영수증', 'cop_c':'제휴사', 'br_c':'점포코드', 'de_dt':'이용일자', 'vst_dt':'방문일자', 'de_hr':'이용시간', 'buy_am':'이용금액', 'chnl_dv':'채널'}, inplace=True)
PD_CLAC.rename(columns={'pd_c':'상품코드', 'pd_nm':'소분류', 'clac_hlv_nm':'대분류', 'clac_mcls_nm':'중분류'}, inplace=True)
BR.rename(columns={'br_c':'점포_코드', 'cop_c':'제휴사', 'zon_hlv':'점포_대분류', 'zon_mcls':'점포_중분류', 'chnl_dv':'채널'}, inplace=True)
LPAY.rename(columns={'cust':'고객번호', 'cop_c':'제휴사', 'rct_no':'영수증', 'de_dt':'이용일자', 'de_hr':'이용시간', 'buy_am':'이용금액', 'chnl_dv':'채널'}, inplace=True)

# %%
COP_U_D = COP_U[(COP_U['제휴사']=='D01') | (COP_U['제휴사']=='D02')]
BR_D = BR[(BR['제휴사']=='D01') | (BR['제휴사']=='D02')]
LPAY_D = LPAY[(LPAY['제휴사']=='D01') | (LPAY['제휴사']=='D02')]

# %% [markdown]
# ## 데이터 살펴보자

# %%
DEMO #1. 고객데모정보
# Out:
#              고객번호  성별  연령대  거주지
# 0      M000034966  여성  40대  Z07
# 1      M000059535  여성  30대  Z12
# 2      M000136117  여성  30대  Z11
# 3      M000201112  여성  50대  Z17
# 4      M000225114  여성  40대  Z17
# ...           ...  ..  ...  ...
# 29908  M999708287  여성  40대  Z10
# 29909  M999770689  여성  30대  Z16
# 29910  M999849895  여성  20대  Z04
# 29911  M999926092  남성  30대  Z08
# 29912  M999962961  여성  50대  Z17
#
# [29913 rows x 4 columns]

# %%
PDDE #2. 유통사 상품 구매 내역
# Out:
#                고객번호           영수증  채널  제휴사     점포코드    상품코드      이용일자  이용시간  \
# 0        M430112881  A01000001113   1  A01  A010039  PD0290  20210101    10
# 1        M646853852  A01000002265   1  A01  A010025  PD1369  20210101    10
# 2        M430112881  A01000003148   1  A01  A010039  PD0290  20210101    10
# 3        M430112881  A01000003148   1  A01  A010039  PD0290  20210101    10
# 4        M430112881  A01000004946   1  A01  A010039  PD0290  20210101    10
# ...             ...           ...  ..  ...      ...     ...       ...   ...
# 4381738  M533286446  E06052119978   2  A06      NaN  PD0507  20211231    23
# 4381739  M533286446  E06052119978   2  A06      NaN  PD0507  20211231    23
# 4381740  M533286446  E06052119978   2  A06      NaN  PD0507  20211231    23
# 4381741  M533286446  E06052119978   2  A06      NaN  PD0507  20211231    23
# 4381742  M533286446  E06052119978   2  A06      NaN  PD0507  20211231    23
#
#             이용금액  구매수량
# 0        15000.0     1
# 1        79700.0     1
# 2        19000.0     1
# 3        19000.0     1
# 4        19000.0     1
# ...          ...   ...
# 4381738  50000.0     1
# 4381739  50000.0     1
# 4381740  50000.0     1
# 4381741  50000.0     1
# 4381742  50000.0     1
#
# [4381743 rows x 10 columns]

# %%
COP_U_D #3. 제휴사 서비스 이용 내역
# Out:
#               고객번호                 영수증  제휴사     점포코드  채널      이용일자      방문일자  \
# 4       M839993508  21101009D015920171  D01  D010614   1  20211010  20211010
# 6       M348796971  21103114D013043421  D01  D010398   1  20211031  20211031
# 17      M348796971  21080712D012470819  D01  D010398   1  20210807  20210807
# 18      M348796971  21081014D011253058  D01  D010398   1  20210810  20210810
# 19      M348796971  21081210D014440902  D01  D010398   1  20210812  20210812
# ...            ...                 ...  ...      ...  ..       ...       ...
# 248282  M321652667  21111614D010746216  D01  D010143   1  20211116  20211116
# 248283  M321652667  21111614D014861900  D01  D010143   1  20211116  20211116
# 248284  M321652667  21092413D013710723  D01  D010143   1  20210924  20210924
# 248285  M321652667  21101812D023790496  D02  D020245   1  20211018  20211018
# 248287  M757518417  21101121D013319941  D01  D011046   1  20211011  20211011
#
#         이용시간   이용금액
# 4          9   2500
# 6         14   4600
# 17        12   7800
# 18        14   5900
# 19        10   4900
# ...      ...    ...
# 248282    14   4500
# 248283    14   6000
# 248284    13  16400
# 248285    12   9100
# 248287    21  17200
#
# [155366 rows x 9 columns]

# %%
PD_CLAC #4. 유통사 상품 카테고리 마스터
# Out:
#         상품코드       소분류       대분류   중분류
# 0     PD0001        소파        가구  거실가구
# 1     PD0002   스툴/리빙의자        가구  거실가구
# 2     PD0003        탁자        가구  거실가구
# 3     PD0004   장식장/진열장        가구  거실가구
# 4     PD0005      기타가구        가구  기타가구
# ...      ...       ...       ...   ...
# 1928  PD1929      여성향수  화장품/뷰티케어    향수
# 1929  PD1930      남성향수  화장품/뷰티케어    향수
# 1930  PD1931    남녀공용향수  화장품/뷰티케어    향수
# 1931  PD1932    남성향수세트  화장품/뷰티케어    향수
# 1932  PD1933  남녀공용향수세트  화장품/뷰티케어    향수
#
# [1933 rows x 4 columns]

# %%
print('-----------대분류-----------\n', set(PD_CLAC['대분류']))
print('\n-----------중분류-----------\n', set(PD_CLAC['중분류']))
print('\n-----------소분류-----------\n', set(PD_CLAC['소분류']))
# Out:
# -----------대분류-----------
#  {'냉장/세탁가전', '생활/렌탈서비스', '아웃도어/레저', '서적/음반/악기', '양곡', '냉장식품', '건해산물', '담배', '문구/사무용품', '완구', '식기/조리기구', '여성의류', '청소/세탁/욕실용품', '건강식품', '상품권', '침구/수예', '패션잡화', '병통조림', '자동차용품', '출산/육아용품', '퍼스널케어', '과일', '주방잡화', '스포츠패션', '축산물', '유아식품', '유아동의류', '커피/차', '건강용품', '수산물', '음료', '헬스/피트니스', '속옷/양말/홈웨어', '시즌스포츠', '화장품/뷰티케어', '원예/애완', '금융/보험서비스', '과자', '기타상품', '남성의류', '영상/음향가전', '공구/안전용품', '주류', '세제/위생', '여행/레저서비스', '계절가전', '가구', '조미료', '테넌트/음식점', '구기/필드스포츠', '냉동식품', '채소', '조리식품', '기타(비상품)', '생활/주방가전', '인테리어/조명', '모바일', '유제품', '대용식', '컴퓨터'}
#
# -----------중분류-----------
#  {'여성일반스포츠의류', '기타', '노트', '보험', '선케어', '서적', '전기용품', '실외놀이/스포츠완구', '메이크업', '스킨케어', '비스킷류', '애견용품', '격투기', '전통주', '축산물통조림', '수산선물세트', '소모품', '남아완구', '건면', '남성속옷', '남성의류아우터', '유아식', '남아의류아우터', '벨트', '여성양말류', '청소세제', '홈웨어', '수예시즌소품', '유아동식기', '낚시', '커피/차세트', '그릇/식기', '거실가구', '남성양말류', '농구', '생활가전', '등산', '여성골프의류', '테니스', '여성속옷', '핸드/풋케어', '남성의류전신', '카페트/러그/매트류', '시계', '여성화', '생수', '소형디지털가전', '여아완구', '기타지갑', '야외용가구', '방향/제습/탈취제', '고양이용품', '주방일회용품', '채소선물세트', '남아의류상의', '남성골프의류', '지류상품권', '욕실용품', '수입과일', '유아안전용품', '탁구', '간편조리', '유아의류전신', '우산/양산류', 'DVD/홈시어터', '기타시즌스포츠', '여성위생용품', '냉동간편식', '남성가방', '맥주', '남성의류상의', '나물류', '장류', '건어물', '사무용지/서식지', '식당', '청소기', '교육보조재', '캐쥬얼가방', '조리기구', '남성패션액세서리', '잎채소', '유아동양말류', '승용완구', '기타애완동물', '액세서리편의용품', '소스류', '밀폐/보관용기', 'TV', '구강케어', '안마/찜질용품', '카메라/캠코더', '수예소품',
세탁세제', '미국산소목심', '유아동선글라스', '유아동식기/식판', '샐러드류', '여성비치웨어', '보석기념품', '유아동스포츠티셔츠/탑', '조미오징어', '미국산소갈비', '여성트렌치코트', '요구르트/청국장제조기', '크래커', '닭안심', '펜던트', '배드민턴화', '캐쥬얼시계', '조각/만들기용품', '유아동스포츠화부속품', '미국산소기타육', '남성코트', '조리기구세트', '여성스커트', '크레파스', '니삭스/오버니삭스', '파충류용품', '여성스웨트셔츠/후드/집업', '남성정장바지', '코다리', '노트북가방', '발찌', '토이캔디', '포장해물류', '곡물/견과차', '여성밍크의류', '유아두유', '유아동컵/물병', '스팀청소기', '기타여성의류세트', '수세미/솔', '즉석면류', '아동우산', '국산돼지항정살', '카메라액세서리', '즉석조림반찬', '제빵용품', '기타야구용품', '교통카드판매', '립밤/립스크럽', '네일케어도구', '남성정장화', '숟가락/젓가락', '바디슬리밍/리프팅', '기타테니스용품', '냉동만두', '남성등산/아웃도어세트', '관악기', '여성카드/명함지갑', '유아동슬립온', '생선선물세트', '솥', '구명조끼/안전용품', '일회용우산', '알림판', '여아패딩', '미니벨로', '단무지', '헤어에센스', '남성스웨트셔츠/후드/집업', '기타구강관리용품', '스포츠선글라스', '반상기세트/홈세트', '여성스포츠패딩', '기타양채류', '유아동샌들', '기타캠핑용품', '네일스티커/스톤류', '약용버섯류', '베이커리', '네일세트', '닭윗날개(봉)', '등산화', '에멀젼/로션', '전기밥솥', '국물용건멸치', '한우안심', '다기류', '등산지팡이/스틱', '음식물건조기', '기타주방정리용품/소모품', '캡슐원두커피', '여아블라우스', '원단', '주방용청소세제', '남성신발부속품', '기타식용유', '냉동홍시', '하이패스', '백화 ...

# %% [markdown]
# 미쳤나 개많네

# %%
BR_D #5. 유통사/제휴사 점포 마스터
# Out:
#         점포_코드  제휴사 점포_대분류  점포_중분류
# 6919  D010001  D01    Z14  Z14004
# 6920  D010002  D01    Z06  Z06013
# 6921  D010003  D01    Z16  Z16016
# 6922  D010004  D01    Z17  Z17021
# 6923  D010005  D01    Z10  Z10028
# ...       ...  ...    ...     ...
# 8760  D020536  D02    Z14  Z14008
# 8761  D020537  D02    Z14  Z14004
# 8762  D020538  D02    Z14  Z14005
# 8763  D020539  D02    Z12  Z12024
# 8764  D020549  D02    Z10  Z10047
#
# [1846 rows x 4 columns]

# %%
print('-----------점포_대분류-----------\n', sorted(set(BR_D['점포_대분류'])))
print('\n-----------점포_중분류-----------\n', sorted(set(BR_D['점포_중분류'])))
# Out:
# -----------점포_대분류-----------
#  ['Z01', 'Z02', 'Z03', 'Z04', 'Z05', 'Z06', 'Z07', 'Z08', 'Z09', 'Z10', 'Z11', 'Z12', 'Z13', 'Z14', 'Z15', 'Z16', 'Z17']
#
# -----------점포_중분류-----------
# %%
LPAY_D #엘페이 결제 내역
# Out:
#               고객번호              영수증  제휴사  채널      이용일자  이용시간   이용금액
# 7       M186539937  210803130266856  D02   1  20210803    13   9600
# 13      M425728822  210803180296681  D02   1  20210803    18  10800
# 39      M029472955  210803220116585  D01   2  20210803    22   3500
# 70      M157433990  210803120263913  D02   1  20210803    12  14800
# 90      M202952355  210803090148501  D01   1  20210803     9  23100
# ...            ...              ...  ...  ..       ...   ...    ...
# 353030  M795528458  210107180179964  D01   1  20210107    18  22460
# 353055  M089155813  210102030196937  D01   2  20210102     3  24100
# 353104  M731182094  210117100135873  D01   2  20210117    10  10100
# 353134  M427026490  210107130151414  D01   2  20210107    13   6000
# 353165  M688241278  210111170102296  D01   1  20210111    17   4400
#
# [17351 rows x 7 columns]

# %% [markdown]
# ## 제휴사 이용 정보 + 고객데모정보

# %%
df = pd.merge(COP_U_D, DEMO, how='left',on='고객번호')
df
# Out:
#               고객번호                 영수증  제휴사     점포코드  채널      이용일자      방문일자  \
# 0       M839993508  21101009D015920171  D01  D010614   1  20211010  20211010
# 1       M348796971  21103114D013043421  D01  D010398   1  20211031  20211031
# 2       M348796971  21080712D012470819  D01  D010398   1  20210807  20210807
# 3       M348796971  21081014D011253058  D01  D010398   1  20210810  20210810
# 4       M348796971  21081210D014440902  D01  D010398   1  20210812  20210812
# ...            ...                 ...  ...      ...  ..       ...       ...
# 155361  M321652667  21111614D010746216  D01  D010143   1  20211116  20211116
# 155362  M321652667  21111614D014861900  D01  D010143   1  20211116  20211116
# 155363  M321652667  21092413D013710723  D01  D010143   1  20210924  20210924
# 155364  M321652667  21101812D023790496  D02  D020245   1  20211018  20211018
# 155365  M757518417  21101121D013319941  D01  D011046   1  20211011  20211011
#
#         이용시간   이용금액  성별  연령대  거주지
# 0          9   2500  남성  70대  Z17
# 1         14   4600  남성  70대  Z17
# 2         12   7800  남성  70대  Z17
# 3         14   5900  남성  70대  Z17
# 4         10   4900  남성  70대  Z17
# ...      ...    ...  ..  ...  ...
# 155361    14   4500  여성  20대  Z13
# 155362    14   6000  여성  20대  Z13
# 155363    13  16400  여성  20대  Z13
# 155364    12   9100  여성  20대  Z13
# 155365    21  17200  여성  20대  Z09
#
# [155366 rows x 12 columns]

# %%
set(df['연령대'])
# Out:
# {'20대', '30대', '40대', '50대', '60대', '70대'}

# %%
df['연령대'] = df['연령대'].apply(lambda x: int(x[:-1]))
set(df['연령대'])
# Out:
# {20, 30, 40, 50, 60, 70}

# %%
df[df['이용일자']!=df['방문일자']]
# Out:
# Empty DataFrame
# Columns: [고객번호, 영수증, 제휴사, 점포코드, 채널, 이용일자, 방문일자, 이용시간, 이용금액, 성별, 연령대, 거주지]
# Index: []

# %% [markdown]
# 이용일자와 방문일자가 다른 경우는 없었고,,

# %%
#이용일자를 월/분기별로
df['이용월'] = df['이용일자'].apply(lambda x:int(str(x)[4:6]))
df['분기'] = df['이용일자'].apply(lambda x: (int(str(x)[4:6])//3) if (int(str(x)[4:6])%3)==0 else (int(str(x)[4:6])//3) + 1)

# %% [markdown]
# ## 상관도를 알아보자

# %%
heatmap_df = df[['채널', '분기', '이용금액', '성별']]
heatmap_df['성별'] = heatmap_df['성별'].apply(lambda x: 1 if x=='남성' else 2)
# Out:
# C:\Users\Seohyeon\AppData\Local\Temp/ipykernel_1652/3242926892.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heatmap_df['성별'] = heatmap_df['성별'].apply(lambda x: 1 if x=='남성' else 2)

# %%
#연령대를 dummy변수로
heatmap_df.loc[:, '20대'] = df['연령대']
heatmap_df.loc[:, '30대'] = df['연령대']
heatmap_df.loc[:, '40대'] = df['연령대']
heatmap_df.loc[:, '50대'] = df['연령대']
heatmap_df.loc[:, '60대'] = df['연령대']
heatmap_df.loc[:, '70대'] = df['연령대']
heatmap_df.replace({'20대':{20:1, 30:0, 40:0, 50:0, 60:0, 70:0},
                   '30대':{20:0, 30:1, 40:0, 50:0, 60:0, 70:0},
                   '40대':{20:0, 30:0, 40:1, 50:0, 60:0, 70:0},
                   '50대':{20:0, 30:0, 40:0, 50:1, 60:0, 70:0},
                   '60대':{20:0, 30:0, 40:0, 50:0, 60:1, 70:0},
                   '70대':{20:0, 30:0, 40:0, 50:0, 60:0, 70:1}}, inplace = True)
# Out:
# C:\Users\Seohyeon\anaconda3\lib\site-packages\pandas\core\indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Seohyeon\anaconda3\lib\site-packages\pandas\core\indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value

# %%
heatmap_df
# Out:
#         채널  분기   이용금액  성별  20대  30대  40대  50대  60대  70대
# 0        1   4   2500   1    0    0    0    0    0    1
# 1        1   4   4600   1    0    0    0    0    0    1
# 2        1   3   7800   1    0    0    0    0    0    1
# 3        1   3   5900   1    0    0    0    0    0    1
# 4        1   3   4900   1    0    0    0    0    0    1
# ...     ..  ..    ...  ..  ...  ...  ...  ...  ...  ...
# 155361   1   4   4500   2    1    0    0    0    0    0
# 155362   1   4   6000   2    1    0    0    0    0    0
# 155363   1   3  16400   2    1    0    0    0    0    0
# 155364   1   4   9100   2    1    0    0    0    0    0
# 155365   1   4  17200   2    1    0    0    0    0    0
#
# [155366 rows x 10 columns]

# %%
heatmap_df.astype(float).corr()
# Out:
#             채널        분기      이용금액        성별       20대       30대       40대  \
# 채널    1.000000  0.017985 -0.000296 -0.024203  0.010032  0.019733 -0.010846
# 분기    0.017985  1.000000 -0.008536 -0.009587  0.016012 -0.001742 -0.009183
# 이용금액 -0.000296 -0.008536  1.000000  0.008158 -0.033425 -0.004511  0.039277
# 성별   -0.024203 -0.009587  0.008158  1.000000 -0.021505 -0.038412  0.045216
# 20대   0.010032  0.016012 -0.033425 -0.021505  1.000000 -0.230596 -0.307545
# 30대   0.019733 -0.001742 -0.004511 -0.038412 -0.230596  1.000000 -0.541212
# 40대  -0.010846 -0.009183  0.039277  0.045216 -0.307545 -0.541212  1.000000
# 50대  -0.014885 -0.000166 -0.012506  0.009252 -0.147925 -0.260315 -0.347182
# 60대  -0.009102  0.000022 -0.007856  0.000631 -0.060131 -0.105818 -0.141129
# 70대  -0.001478  0.003164 -0.012490 -0.017203 -0.028870 -0.050805 -0.067759
#
#            50대       60대       70대
# 채널   -0.014885 -0.009102 -0.001478
# 분기   -0.000166  0.000022  0.003164
# 이용금액 -0.012506 -0.007856 -0.012490
# 성별    0.009252  0.000631 -0.017203
# 20대  -0.147925 -0.060131 -0.028870
# 30대  -0.260315 -0.105818 -0.050805
# 40대  -0.347182 -0.141129 -0.067759
# 50대   1.000000 -0.067881 -0.032591
# 60대  -0.067881  1.000000 -0.013248
# 70대  -0.032591 -0.013248  1.000000

# %%
#colormap = plt.cm.PuBu 
plt.figure(figsize=(10, 10)) 
plt.title("Correlation", y = 1.05, size = 15) 
sns.heatmap(heatmap_df.astype(float).corr() , linewidths = 0.1, vmax = 1.0, 
            square = True, linecolor = "white", annot = True, annot_kws = {"size" : 12})
# Out:
# <AxesSubplot:title={'center':'Correlation'}>

# %% [markdown]
# 머 이런 쓰레기상관도가...

# %%
heatmap_df2 = heatmap_df.copy()
heatmap_df2['이용금액'] = np.log(heatmap_df2['이용금액'])

# %%
heatmap_df2
# Out:
#         채널  분기      이용금액  성별  20대  30대  40대  50대  60대  70대
# 0        1   4  7.824046   1    0    0    0    0    0    1
# 1        1   4  8.433812   1    0    0    0    0    0    1
# 2        1   3  8.961879   1    0    0    0    0    0    1
# 3        1   3  8.682708   1    0    0    0    0    0    1
# 4        1   3  8.496990   1    0    0    0    0    0    1
# ...     ..  ..       ...  ..  ...  ...  ...  ...  ...  ...
# 155361   1   4  8.411833   2    1    0    0    0    0    0
# 155362   1   4  8.699515   2    1    0    0    0    0    0
# 155363   1   3  9.705037   2    1    0    0    0    0    0
# 155364   1   4  9.116030   2    1    0    0    0    0    0
# 155365   1   4  9.752665   2    1    0    0    0    0    0
#
# [155366 rows x 10 columns]

# %%
#colormap = plt.cm.PuBu 
plt.figure(figsize=(10, 10)) 
plt.title("Correlation", y = 1.05, size = 15) 
sns.heatmap(heatmap_df2.astype(float).corr() , linewidths = 0.1, vmax = 1.0, 
            square = True, linecolor = "white", annot = True, annot_kws = {"size" : 12})
# Out:
# <AxesSubplot:title={'center':'Correlation'}>

# %% [markdown]
# 아 일단 넘어간다

# %% [markdown]
# ## 그래프 그리자

# %%
df.columns
# Out:
# Index(['고객번호', '영수증', '제휴사', '점포코드', '채널', '이용일자', '방문일자', '이용시간', '이용금액',
#        '성별', '연령대', '거주지', '이용월', '분기'],
#       dtype='object')

# %%
# 이용금액 단위 변경 (천원)
df['이용금액'] = df['이용금액']/1000

# %% [markdown]
# ### 월별 이용 데이터

# %%
df_월별_수= df[['이용월']].groupby(['이용월'], as_index=False).size()
df_월별_수
# Out:
#     이용월   size
# 0     1  10991
# 1     2  11901
# 2     3  12884
# 3     4  13356
# 4     5  13668
# 5     6  13281
# 6     7  14265
# 7     8  14516
# 8     9  12480
# 9    10  13864
# 10   11  11991
# 11   12  12169

# %%
sum(df_월별_수['size'])
# Out:
# 155366

# %%
len(df)
# Out:
# 155366

# %%
#월별 이용 확인
df_월별_합 = df[['이용월', '이용금액']].groupby(['이용월'], as_index=False).sum()
df_월별_평균 = df[['이용월', '이용금액']].groupby(['이용월'], as_index=False).mean()
df_월별_수= df[['이용월']].groupby(['이용월'], as_index=False).size()

df_월별_합.plot(x='이용월', y='이용금액', kind='bar', title='월별 총 이용금액', color = sns.color_palette('PuRd'))
df_월별_평균.plot(x='이용월', y='이용금액', kind='bar', title='월별 평균 이용금액', color = sns.color_palette('PuRd'))
df_월별_수.plot(x='이용월', y='size', kind='bar', title='월별 이용 빈도', color = sns.color_palette('PuRd'))
# Out:
# <AxesSubplot:title={'center':'월별 이용 빈도'}, xlabel='이용월'>

# %% [markdown]
# ### 분기별 이용데이터

# %%
#분기별 이용 확인
df_분기별_합 = df[['분기', '이용금액']].groupby(['분기'], as_index=False).sum()
df_분기별_평균 = df[['분기', '이용금액']].groupby(['분기'], as_index=False).mean()
df_분기별_수= df[['분기']].groupby(['분기'], as_index=False).size()

df_분기별_합.plot(x='분기', y='이용금액', kind='bar', title='분기별 총 이용금액', color = sns.color_palette('PuRd'))
df_분기별_평균.plot(x='분기', y='이용금액', kind='bar', title='분기별 평균 이용금액', color = sns.color_palette('PuRd'))
df_분기별_수.plot(x='분기', y='size', kind='bar', title='분기별 이용 빈도', color = sns.color_palette('PuRd'))
# Out:
# <AxesSubplot:title={'center':'분기별 이용 빈도'}, xlabel='분기'>

# %% [markdown]
# ## 채널별

# %%
df_채널별_합 = df[['채널', '이용금액']].groupby(['채널'], as_index=False).sum()
df_채널별_평균 = df[['채널', '이용금액']].groupby(['채널'], as_index=False).mean()
df_채널별_수= df[['채널']].groupby(['채널'], as_index=False).size()

df_채널별_합.plot(x='채널', y='이용금액', kind='bar', title='채널별 총 이용금액', color = sns.color_palette('PuRd'))
df_채널별_평균.plot(x='채널', y='이용금액', kind='bar', title='채널별 평균 이용금액', color = sns.color_palette('PuRd'))
df_채널별_수.plot(x='채널', y='size', kind='bar', title='채널별 이용 빈도', color = sns.color_palette('PuRd'))
# Out:
# <AxesSubplot:title={'center':'채널별 이용 빈도'}, xlabel='채널'>

# %% [markdown]
# 채널이 다 online뿐,, 그냥 offline 없이 하자~~~~

# %% [markdown]
# ## 이용시간별

# %%
df_이용시간별_합 = df[['이용시간', '이용금액']].groupby(['이용시간'], as_index=False).sum()
#df_이용시간별_평균 = df[['이용시간', '이용금액']].groupby(['이용시간'], as_index=False).mean()
df_이용시간별_수= df[['이용시간']].groupby(['이용시간'], as_index=False).size()

df_이용시간별_합.plot(x='이용시간', y='이용금액', kind='bar', title='이용시간별 총 이용금액', color = sns.color_palette('PuRd'))
#df_이용시간별_평균.plot(x='이용시간', y='이용금액', kind='bar', title='이용시간별 평균 이용금액', color = sns.color_palette('PuRd'))
df_이용시간별_수.plot(x='이용시간', y='size', kind='bar', title='이용시간별 이용 빈도', color = sns.color_palette('PuRd'))
# Out:
# <AxesSubplot:title={'center':'이용시간별 이용 빈도'}, xlabel='이용시간'>

# %% [markdown]
# ### 연령대별

# %%
heatmap_df = df[['연령대', '이용시간', '이용금액']]
heatmap_df
#colormap = plt.cm.PuBu 
plt.figure(figsize=(10, 10)) 
plt.title("Correlation", y = 1.05, size = 15) 
sns.heatmap(heatmap_df.astype(float).corr() , linewidths = 0.1, vmax = 1.0, 
            square = True, linecolor = "white", annot = True, annot_kws = {"size" : 12})
# Out:
# <AxesSubplot:title={'center':'Correlation'}>

# %%
df
# Out:
#               고객번호                 영수증  제휴사     점포코드  채널      이용일자      방문일자  \
# 0       M839993508  21101009D015920171  D01  D010614   1  20211010  20211010
# 1       M348796971  21103114D013043421  D01  D010398   1  20211031  20211031
# 2       M348796971  21080712D012470819  D01  D010398   1  20210807  20210807
# 3       M348796971  21081014D011253058  D01  D010398   1  20210810  20210810
# 4       M348796971  21081210D014440902  D01  D010398   1  20210812  20210812
# ...            ...                 ...  ...      ...  ..       ...       ...
# 155361  M321652667  21111614D010746216  D01  D010143   1  20211116  20211116
# 155362  M321652667  21111614D014861900  D01  D010143   1  20211116  20211116
# 155363  M321652667  21092413D013710723  D01  D010143   1  20210924  20210924
# 155364  M321652667  21101812D023790496  D02  D020245   1  20211018  20211018
# 155365  M757518417  21101121D013319941  D01  D011046   1  20211011  20211011
#
#         이용시간  이용금액  성별  연령대  거주지  이용월  분기
# 0          9   2.5  남성   70  Z17   10   4
# 1         14   4.6  남성   70  Z17   10   4
# 2         12   7.8  남성   70  Z17    8   3
# 3         14   5.9  남성   70  Z17    8   3
# 4         10   4.9  남성   70  Z17    8   3
# ...      ...   ...  ..  ...  ...  ...  ..
# 155361    14   4.5  여성   20  Z13   11   4
# 155362    14   6.0  여성   20  Z13   11   4
# 155363    13  16.4  여성   20  Z13    9   3
# 155364    12   9.1  여성   20  Z13   10   4
# 155365    21  17.2  여성   20  Z09   10   4
#
# [155366 rows x 14 columns]

# %%
df_연령대별_합 = df[['연령대', '이용금액']].groupby(['연령대'], as_index=False).sum()
#df_연령대별_평균 = df[['연령대', '이용금액']].groupby(['연령대'], as_index=False).mean()
#df_연령대별_수= df[['연령대']].groupby(['연령대'], as_index=False).size()

df_연령대별_합.plot(x='연령대', y='이용금액', kind='bar', title='연령대별 총 이용금액', color = sns.color_palette('PuRd'))
#df_연령대별_평균.plot(x='연령대', y='이용금액', kind='bar', title='연령대별 평균 이용금액', color = sns.color_palette('PuRd'))
#df_연령대별_수.plot(x='연령대', y='size', kind='bar', title='연령대별 이용 빈도', color = sns.color_palette('PuRd'))
# Out:
# <AxesSubplot:title={'center':'연령대별 총 이용금액'}, xlabel='연령대'>

# %%
#연령대별 시간대
df_연령대_시간 = df[['연령대', '이용시간', '이용금액']].groupby(['연령대','이용시간'], as_index=False).sum()
df_연령대_시간
# Out:
#      연령대  이용시간    이용금액
# 0     20     0  748.23
# 1     20     1  593.54
# 2     20     2  414.42
# 3     20     3  144.30
# 4     20     4  100.10
# ..   ...   ...     ...
# 133   70    18  376.70
# 134   70    19  243.65
# 135   70    20   78.45
# 136   70    21   55.50
# 137   70    22   25.10
#
# [138 rows x 3 columns]

# %%
df_연령대_시간[df_연령대_시간['연령대']==20].plot(x='이용시간', y='이용금액', kind='bar', title='20대 총 이용금액', color = sns.color_palette('PuRd'))
df_연령대_시간[df_연령대_시간['연령대']==30].plot(x='이용시간', y='이용금액', kind='bar', title='30대 총 이용금액', color = sns.color_palette('PuRd'))
df_연령대_시간[df_연령대_시간['연령대']==40].plot(x='이용시간', y='이용금액', kind='bar', title='40대 총 이용금액', color = sns.color_palette('PuRd'))
df_연령대_시간[df_연령대_시간['연령대']==50].plot(x='이용시간', y='이용금액', kind='bar', title='50대 총 이용금액', color = sns.color_palette('PuRd'))
df_연령대_시간[df_연령대_시간['연령대']==60].plot(x='이용시간', y='이용금액', kind='bar', title='60대 총 이용금액', color = sns.color_palette('PuRd'))
df_연령대_시간[df_연령대_시간['연령대']==70].plot(x='이용시간', y='이용금액', kind='bar', title='70대 총 이용금액', color = sns.color_palette('PuRd'))
# Out:
# <AxesSubplot:title={'center':'70대 총 이용금액'}, xlabel='이용시간'>

# %% [markdown]
# ## 거주지별

# %%
df_거주지별_합 = df[['거주지', '이용금액']].groupby(['거주지'], as_index=False).sum()
#df_연령대별_평균 = df[['연령대', '이용금액']].groupby(['연령대'], as_index=False).mean()
df_거주지별_수= df[['거주지']].groupby(['거주지'], as_index=False).size()

df_거주지별_합.plot(x='거주지', y='이용금액', kind='bar', title='거주지별 총 이용금액', color = sns.color_palette('PuRd'))
#df_연령대별_평균.plot(x='연령대', y='이용금액', kind='bar', title='연령대별 평균 이용금액', color = sns.color_palette('PuRd'))
df_거주지별_수.plot(x='거주지', y='size', kind='bar', title='거주지별 이용 빈도', color = sns.color_palette('PuRd'))
# Out:
# <AxesSubplot:title={'center':'거주지별 이용 빈도'}, xlabel='거주지'>

# %%
df_거주지별_합.sort_values('이용금액', ascending=False)
# Out:
#     거주지       이용금액
# 9   Z10  423976.98
# 16  Z17  403151.79
# 15  Z16  147363.16
# 10  Z11  105721.27
# 3   Z04   98060.64
# 5   Z06   73204.63
# 12  Z13   57202.78
# 7   Z08   44235.06
# 13  Z14   42032.76
# 11  Z12   36053.15
# 14  Z15   34788.65
# 4   Z05   33189.61
# 8   Z09   30863.51
# 2   Z03   29234.32
# 0   Z01   22377.10
# 6   Z07    7634.47
# 1   Z02    3252.73

# %%
custom_palette = sns.color_palette("Set3", 6)
sns.histplot(data=df, x='거주지', hue='연령대', palette = custom_palette)
# Out:
# <AxesSubplot:xlabel='거주지', ylabel='Count'>
